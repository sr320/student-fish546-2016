# %% [markdown]
# # Some quick stats on Assemblies (March v May)

# %%
# !ls /Volumes/web/fish546/sr320/
# Out:
# scaffold.fa.fill

# %%
# !head -2 /Volumes/web/fish546/sr320/scaffold.fa.fill
# Out:
# >scaffold1
# ...

# %%
# !fgrep -c ">" /Volumes/web/fish546/sr320/scaffold.fa.fill
